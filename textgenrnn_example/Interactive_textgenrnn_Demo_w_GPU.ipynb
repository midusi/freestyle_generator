# %% [markdown]
# #  Interactive textgenrnn Demo w/ GPU
#
# by [Max Woolf](http://minimaxir.com)
#
# *Last updated: December 2nd, 2018*
#
# Generate text using a pretrained neural network with a few lines of code, or easily train your own text-generating neural network of any size and complexity, **for free on a GPU using Collaboratory!**
#
# For more about textgenrnn, you can visit [this GitHub repository](https://github.com/minimaxir/textgenrnn).
#
#
# To get started:
#
# 1. Copy this notebook to your Google Drive to keep it and save your changes.
# 2. Make sure you're running the notebook in Google Chrome.
# 3. Run the cells below:

# %%
# %tensorflow_version 1.x
# !pip install -q textgenrnn
from google.colab import files
from textgenrnn import textgenrnn
from datetime import datetime
import os
# Out:
# TensorFlow 1.x selected.
# Using TensorFlow backend.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.

# %% [markdown]
# Set the textgenrnn model configuration here: the default parameters here give good results for most workflows. (see the [demo notebook](https://github.com/minimaxir/textgenrnn/blob/master/docs/textgenrnn-demo.ipynb) for more information about these parameters)
#
# If you are using an input file where documents are line-delimited, make sure to set `line_delimited` to `True`.

# %%
model_cfg = {
    'word_level': True,   # set to True if want to train a word-level model (requires more data and smaller max_length)
    'rnn_size': 128,   # number of LSTM cells of each layer (128/256 recommended)
    'rnn_layers': 3,   # number of LSTM layers (>=2 recommended)
    'rnn_bidirectional': False,   # consider text both forwards and backward, can give a training boost
    'max_length': 10,   # number of tokens to consider before predicting the next (20-40 for characters, 5-10 for words recommended)
    'max_words': 10000,   # maximum number of words to model; the rest will be ignored (word-level model only)
}

train_cfg = {
    'line_delimited': False,   # set to True if each text has its own line in the source file
    'num_epochs': 30,   # set higher to train the model for longer
    'gen_epochs': 5,   # generates sample text from model after given number of epochs
    'train_size': 0.8,   # proportion of input data to train on: setting < 1.0 limits model from learning perfectly
    'dropout': 0.0,   # ignore a random proportion of source tokens each epoch, allowing model to generalize better
    'validation': False,   # If train__size < 1.0, test on holdout dataset; will make overall training slower
    'is_csv': False   # set to True if file is a CSV exported from Excel/BigQuery/pandas
}

# %% [markdown]
# In the Colaboratory Notebook sidebar on the left of the screen, select *Files*. From there you can upload files:
#
# ![alt text](https://i.imgur.com/TGcZT4h.png)
#
# Upload **any text file** and update the file name in the cell below, then run the cell.

# %%
file_name = "concatenated.txt"
model_name = 'webscrapped2'   # change to set file name of resulting trained models/texts

# %% [markdown]
# The next cell will start the actual training. And thanks to the power of Keras's CuDNN layers, training is super-fast when compared to CPU training on a local machine!
#
# Ideally, you want a training loss less than `1.0` in order for the model to create sensible text consistently.

# %%
textgen = textgenrnn()
textgen.reset()
train_function = textgen.train_from_file if train_cfg['line_delimited'] else textgen.train_from_largetext_file

train_function(
    file_path=file_name,
    new_model=True,
    num_epochs=train_cfg['num_epochs'],
    gen_epochs=train_cfg['gen_epochs'],
    batch_size=1024,
    train_size=train_cfg['train_size'],
    dropout=train_cfg['dropout'],
    validation=train_cfg['validation'],
    is_csv=train_cfg['is_csv'],
    rnn_layers=model_cfg['rnn_layers'],
    rnn_size=model_cfg['rnn_size'],
    rnn_bidirectional=model_cfg['rnn_bidirectional'],
    max_length=model_cfg['max_length'],
    dim_embeddings=100,
    word_level=model_cfg['word_level'])
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# ####################
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  no me digas que no me digas " no " ,
# que me quede sin un beso ,
# que me parta un rayo ,
# que me parta un rayo ,
# que me parta un rayo ,
# que me parta un rayo ,
# que me parta un rayo ,
# que me parta un rayo ,
# que me parta un rayo ,
# que me parta un rayo ,
# que me parta un rayo ,
# que me parta un rayo ,
# que me parta un rayo ,
# que me parta un rayo ,
# que me parta un rayo ,
# que me parta un rayo ,
# que me parta un rayo ,
# que me parta un rayo ,
# que me parta un rayo ,
# que me parta un rayo ,
# que me parta un rayo ,
# que me parta un rayo ,
# que me parta un rayo ,
# que me parta un rayo ,
# que me parta un rayo ,
# que me parta un rayo ,
# que me parta un rayo ,
# que me parta un rayo ,
# que me parta un rayo ,
# que me parta un rayo ,
# que me parta un rayo ,
# que me parta un rayo ,
# que me parta un rayo ,
# que me parta un rayo ,
# que me parta un rayo ,
# que me parta un rayo ,
# que me parta un rayo ,
# que me parta un rayo ,
# que me parta un rayo ,
# que me parta un rayo ,
# que me parta un rayo ,
# que me parta un rayo ,
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ####################
# Temperature: 0.5
# ####################
# no hay mas , no hay mas que hablar
# si me entiendes me lo hago
# yo no me lo digo ni lo que hago ,
# ni lo hago , ni lo que hago , ni lo que hago ,
# ni por lo que hago , lo hago y lo hago por mí .
#
#
#
#  y no me acuerdo de lo que me decían ,
# me gusta que te y me sentía un ,
# pero no me lo estoy follando ,
# yo no sé qué hacer si buscas una salida ,
# y si te vas a ser feliz ,
# y te jode que te ,
# que te miren con la luna , no ,
# no es el sol , no existe rival ,
# no hay que se resista la vida ,
# la vida de mi vida ,
# me la vida que me ha dejado ,
# y me quede sin querer ,
# que me sobra hasta que se diga que no soy ,
# que voy a ser un gran gran parte de mi vida
# que solo me quede sin ti
# y no sé , no sé , no sé , no sé , no sé , no . . .
# no puedo ni en ti , ni ni ni ni ni yo ,
# pero no me conformo con ,
# lo que me sobra es ,
# mi rap es pura , mi rap es sentimiento
# y mi música es el que manda en el resto de un
# yo soy uno mismo , siempre lo que quieras ,
# no , no , no , no , no ,
# no , no , no ,
#
#
#  la poesía en el cuello se cree en un mundo
# una realidad que nace libre
# a la gente que se siente
# cuando la luz se apaga y se apaga hasta que el sol se esconda ,
# y la noche se apaga hasta el viento ,
# no es un bálsamo ,
# necesitamos de un esfuerzo de amor ,
# de la realidad en el mundo de un sueño
# donde las que no hablan y no tienen la talla
# y luego la cagan ,
# ya no se ni dónde se gana ,
# y es que se que se perdió y se cree ,
# el que vive y no se vive en el momento .
#
#
#
#  ahora no pienso callarme , no , no , no , no , no , no , no , no . . .
# no hay prisa en mis ojos ,
# no hay nada que me .
#
#
#
#  no quiero que me digas que no soy ,
# que no me lo ,
# pero no lo sé , no lo sé ,
# es lo que me motiva ,
# por eso no me acuerdo de mi mismo ,
# porque a veces me da que levantar ,
# que en el fondo me lleve a mis hijos de otros ,
# aunque no suene grave ,
# yo no estaré a ningún lado ,
# yo no sé que hacer ,
# si me ves en el espejo ,
# la única que me quita la vida ,
# la vida es un combate y la vida es una ,
# es el hombre de la ley del hip hop .
#
#
#
#  es
#
# la mano en el lavabo
# que no me en el bar y que me coma el sueño
# es algo mas difícil que el
# al final del túnel ,
# que el mundo no se acaba .
#
#
# ( x2 )
# si no lo hago lo que hago es porque no lo hago ,
# como el gato lo que quiere ,
# pero no de mi ,
# si no me lees ,
# si me gustan los problemas que nunca jamás .
#
#
#
#  ( x2 )
# no me digas que no debo de ti que no ,
# no me digas que no debo ,
# que no me , que no me , que no me ,
# que no me , que no me , que no ,
# que no me ,
# que no me , que no me , que no me ,
# que no , que no me , que no ,
# que no me digas que no me digas que no me ,
# pero no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no . . .
#
#
#
#  no quiero ser feliz ,
# quiero que el miedo a que me lleve el viento
# y el momento me se en el pecho
# y a veces me canso de pensar en ti ,
# en éste mundo no hay , hay un artista ,
# porque el resto es un gran parte de mí ,
#
#
# ####################
# Temperature: 1.0
# ####################
# aún no se bajan como big ,
# ni los dedos , los artistas ,
# están igual donde ellos representa la zona ,
# el maestro del cena , shotta al señor .
# i know this i mean i know my then it ' s all right .
# she ' s the best to ever forget it , i ' m stay ,
# there ' s an everyday and we new bitch ,
# and the is not make the power out my shit ,
# and i was that shit and my shit would turn up let the run , can ' t got now on ,
# he a little house a love when they get with the on ,
# and i don ' t know yah , what i girl deep like that all hell ,
# and if we , if you start cold , and soul fi
#
#
#
#  el letargo , me quemo en mi con el papel
# pasan las estaciones
# y la lio
# me voy a dejar que esta fiesta
# la destroza todo lento , esto es así vente ,
# y tú no sabes de mi levanta ,
# y nadie me motiva cuando decías :
# yo caigo en este happy como lleno de besos .
# vivo con la cruz de seguir incluso he aprendido .
#
#  yo estaré en cumaná ,
# yo estaré en cumaná ,
# en otro mundo hay sombras , oasis en el rap es cruel ,
# solo pregunto por todo , pero no lo
# porque yo soy un suicida que no supo que te vaya bien ,
# entiendo tu papel en mi pecho van pisando en mi retrato ,
#
# y esa nube en negra ,
# escribo en horas muertas gratis ni ciudad ,
# nada que es algo trofeo .
# tantas historias se vacía desayunar
# barro con mis alegrías ( de mi música ! )
# a veces me callo y fondo de vértigo
# y piensen que antes me he a ver
# pensando en las horas asi y saca un libro alta y comienza la escuela
# cada esquina en mi barrio solo sale
# cuando el autoestima está grabado
# pero ella sabe quien quiera que quiera
# puede que no te , hazme caso ,
# lanzo mil esposas y te mil vez más puedo ver morir
# los 2000 llenan de humo seco terraza
# así que o . . . sin su .
# pírate escuchando las manos como la hienas ,
# digo rey ,
# la rima es rara ,
# pero al presidente del piso ,
# quieren gigantes , levantamos , en el lodo !
# ese es el misterio sobre un vergüenza si respiras
# mentes ! ! fuego nuevo , ¡oh ! arriba ,
# pa ' un consejo que pase mis momentos ,
# cambia de la mano si la world duele yo lo que soñar
# es que empiece el roce , cual ponerme en paz interior
# music en el diario
# el primero que en las parques que soltar
# seduce y blanca
# nunca más sabe ya que la palabra hoy te
# he cometido muchos un planeta usando como un tema
# como a ver amanecer es para ser su esclava ,
# un milagro del se ataca y su carne es suyo ,
# y es que eres suya pa mis venas , y mi reino ,
#
# social que le salva de este mundo entero
# que hay muchos padres solos al folio
# en verdad que parecen la pasta y yo ,
# vi , esto es cabron , perra no ,
# son nuevos rappers a mi nunca había envidia ,
# en esas cosas a mi esta vida de personas que hablan de veras
# sigo aqui mi mente reconoce ,
# mi vida escapa y mis párpados eran hardcore ,
# me tengo mil dramas en mi abuelo perdido el
# sabor navegando entre .
# no hay dinero si hay vidas que no tenemos conciencia ,
# el lío no es así aunque esté girando el camino no es .
# voy sin guión , nunca muere ,
# tengo razones que se cuidan , no hay sentimiento que olvidar , es lo que ocurre
# pero todo se nota pero quiero paz ,
# quizás hoy , chica ¿sabes como todo habrán menos al partir ,
# todo lo que sé fue , lo sé de nuevo .
# si dejas las cadenas y solo la muerte .
# cuando te dije que ella tenía a tu te lo ,
# y eso que vamos y que se muera .
# cuando me sombra ya voy medio muriendo .
# esa solar es mi compañera . . . me vio crecer y no me arrepiento . . .
# hasta que la muerte baje . . .
# no estoy ni puto . . .
#
#  sigo defendiendo mi peso ahogado .
# he tenido varios años
# y me que tus palabras sean estos malos que antes hay en la arena .
# jesús , muda , el diablo en todos
# me pagan los con cadenas
# me
#
# Epoch 6/30
# 3468/3468 [==============================] - 271s 78ms/step - loss: 3.7059
# Epoch 7/30
# 3468/3468 [==============================] - 275s 79ms/step - loss: 3.6506
# Epoch 8/30
# 3468/3468 [==============================] - 264s 76ms/step - loss: 3.6037
# Epoch 9/30
# 3468/3468 [==============================] - 264s 76ms/step - loss: 3.5608
# Epoch 10/30
# 3468/3468 [==============================] - 262s 76ms/step - loss: 3.5228
# ####################
# Temperature: 0.2
# ####################
#
#  no me digas que no ,
# que no me , que no me , que no me ,
# que no me , que no me ,
# que no me , que no me , que no me ,
# que no me , que no me , que no me ,
# que no me , que no me ,
# que no me , que no me ,
# que no me , que no me , que no me ,
# que no me , que no me , que no me ,
# que no me , que no me , que no me ,
# que no me , que no me , que no me ,
# que no me , que no me , que no me ,
# que no me , que no me ,
# que no me , que no me , que no me ,
# que no me , que no me , que no me ,
# que no me , que no me , que no me ,
# que no me , que no me ,
# que no me , que no me , que no me ,
# que no me , que no me , que no me ,
# que no me , que no me , que no me ,
# que no me , que no me , que no me ,
# que no me , que no me ,
# que no me , que no me , que no me ,
# que no me , que no me , que no me ,
# que no me , que no me , que no me ,
# que no me ,
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# .
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ####################
# Temperature: 0.5
# ####################
# y es que todo se va
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  me voy a como yo ,
# no me hables de más , no ,
# no soy un mc , no soy un mago ,
# ni el dinero ni la cartera , ni el dinero ,
# no hay más , pero no hay más que otro .
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  tu mirada perdida ,
# que la vida es un regalo ,
# que le follen al que me hizo ,
# me lo dijo mi madre ,
# y ahora no me verás mentir ,
# si no me
#
# el espejo y el cielo hay que no te importa el ,
# el amor no se compra en la cartera ,
# y lo que no pudo ser ,
# pero no sé si es el final .
#
#
#
#  la vida es un segundo , la vida es un regalo ,
# la vida es una vida ,
# y un minuto de silencio que no se puede ni que ,
# que la vida es un regalo y no lo sé ,
# yo creo en dios , creo en mí , creo en el amor ,
# yo ya sé , de pequeño eres tú ,
# tú no te lo tengo ,
# te lo juro , pero no lo he hecho ,
# y en que si lo que fuera es el momento
# ahora que todo lo que hacemos es un ramo de .
#
#
#
#  y tú sigues a mi lado ,
# no me hables de más de lo que yo te quiero ,
# más de lo que tienes ,
# que no te gusta ,
# que te , que te pegas ,
# te pegas , te lo ,
# lo hacemos todo ,
# no hay ningún misterio ,
# en el metro de la fama , un ,
# de un libro de mi padre , de un día y de otro
# me dijo , no te pases de ti ,
# que no te lo diga , que te lo que eres y no lo ,
# yo no sé si es el amor que no ,
# si el amor es ciego ,
# y no habrá más que hablar ,
# no hay más que un amigo que
#
#
#  no tengo na ' más ,
# pa ' acá , dame de na ,
# no le puede vivir sin ti ,
# no le deja vivir ,
# jamás verás nadie , no se puede hacer nada ,
# lo que os gusta es mi secreto y en mi voz ,
# en el intento de tu vida ,
# la mente es lo único que te quiero ,
# y es que no tengo tiempo para perder ,
# no quiero vivir sin ti ,
# no puedo vivir sin ti ,
# sin ti no hay tiempo que perder ,
# te juro que no soy un cobarde ,
# que me ama y te puede matar ,
# lo que te mata por ti ,
# te juro que no te tengo ,
# y no voy a , no voy a ser que me ,
# tengo la mente en la ,
# me siento como un niño , que no me ,
# que yo no soy un rapero , lo que quieres ser
# en mi , me han visto en la calle ,
# no tengo tiempo en la cartera vacía ,
# y si me fuera la primera vez ,
# si no fuera por esta presión ,
# la mirada de un niño que no quiere ,
# y el que se quedó en el tintero ,
# de lo que no pude ver ,
# y ahora que no ,
# no me digas que no me .
#
#
#
#  y así es como debe de hacer
# que nos a la vida y cada uno de su lugar ,
# y no hay nada más puro que el anterior .
#
#
#
#
#
# ####################
# Temperature: 1.0
# ####################
# nada i don ' t made me .
# mi cuarto m y lo cojo duro en las últimas .
# y voy , ja ! contarte historias :
# comer ustedes a los que se mean como ha venido ,
# tú quieres ser actor pupilas ,
# ya sé nena , soy rapero , , como noria .
# guardando 5 para acabar con el tema del hip hop
# a eso y plasmo el rap en las gafas de cristal
# y verás que le pudiste quedar a ver
# y no interesan nunca a nadie
# ni yo mientras mis viejos me
# yo hago rap de alma , entre tantos player .
# lo llamo diversión , no ' ve ,
# esto era real sí , los raperos siempre estuvieron ahí
# no hay más que cualquier loca odiando a un niño ,
# con creer convencido , no complejos ,
# viendo el ego , sueños al que el tempo
# y echando de menos como el uso de dedo en
# y sobran buenos pocos camas vacías de .
# los he dormido con todo y entre y . . .
# soñar , soñar ser preciso .
# yo solo puedo ayudarte antes a apreciar que te ,
# tú eres un astro , tú , yo ,
# pocas cosas piensas que es otra manera ,
# es lo que nos vuelve ,
# pero para levantarte a pensar que tú te hayas ido
# es una brisa para abrir el corazón ,
# cansado de esperar lamentos que los mares me la suda en poder plasmar lo sé .
# en los cascos , no dura el racismo ya .
# siento que acá no podrán jamás ,
#
#
# han para dar vueltas ,
# hacerte una paja en lo que te va a curar ,
# las tienes siempre que rica , ain ' t cash ,
# la lluvia de la guerra , la vida entera
# vuelve preparando , tu realidad no es fácil ,
# la verdad es saber cambiarme y vivir sonriendo .
#
#  o si tal va pa darte un pal resto ?
# estamos preparados para siempre , tú sonríe ,
# dios ya está en la ruina ,
# no soy el monstruo que respiro ,
# cojo el micro y quédate lo ves ,
# te pongo al loro no se tiene un futuro oscuro ,
# nos el misterio bien y ya es que ,
# aquí despacito se los focos . .
#
#
# la fiesta es hoy , yo lucho contra la inopia ,
# le vigilando odio a unos cuantos crecido sin el gas ,
# mi teléfono a fumar , , lo aprendí ,
# pero le escribe que ansío , , y aunque nunca me ,
# viva la manera nunca con la naturaleza . . .
#
#  ey , acabado aquí no nos conocemos ,
# ya seremos la paz , el humo pasar , esque . . .
# entro en cualquier sitio mi salón de ,
# que la madre de la imagen que no se les ,
# dejé una huella con la ropa de loto , por el lado . . .
# conoce tanto elegir lenguas llorar por ello
# como tu ex en noches de laboratorio mi trabajando en mi cama ,
# la vida es intentes perdida por dentro ,
# pero solo hay un humo dentro me mata rompiendo el suelo
#
# hay muchos como una máquina sin caer ,
# porque nunca gustó vivir , ni acompañado de no apagar mi cielo en esta mierda .
#
#  socio , es después de fallar ,
# bejito va una ' a este papi ,
# ¡ey !
# k .
# pongan otras cosas
# no son , pero no son como san .
# ya lo hemos sentido , las reglas para vivir en el ,
# he tenido un sitio ,
# fuera de la fosa que le vendí por dentro alguna ,
# echo su porvenir , me llaman y no me ha ,
# culpa de estos años como un jardín ,
# a otras no será otro hijo de puta droga
# barcelona , arriba su san lee
# perdidos a la orilla a la muerte
# y es que me cuesta .
# rezando a veces la madre va a hundirme en este camino ,
# podría haberme juntas los fallos .
#
#
#
#  ? si no sabes quién es , siéntete ágil ,
# lo entendí , casi lo no viste ,
# esto estaba escrito en un iphone trajo que tuve que cerrar .
# amor artificial , para mi familia ,
# soy el dueño de cada ser yo
# me siento envidia y planos como capricho ,
# a veces te encuentran un zombie , entorno lo ponte a todos tío hoy , creo en ti .
#
#
# en la calle solo pueden la iglesia ,
# y la es vuestro mac ,
# porque esto será casi , pero la verdad es que yo no hay bote ,
# soy psicólogo entienda como lo supiera con gente ,
# mi tanto madre llama de mí ,
#
# Epoch 11/30
# 3468/3468 [==============================] - 262s 76ms/step - loss: 3.4871
# Epoch 12/30
# 3468/3468 [==============================] - 263s 76ms/step - loss: 3.4558
# Epoch 13/30
# 3468/3468 [==============================] - 261s 75ms/step - loss: 3.4225
# Epoch 14/30
# 3468/3468 [==============================] - 267s 77ms/step - loss: 3.3866
# Epoch 15/30
# 3468/3468 [==============================] - 262s 76ms/step - loss: 3.3484
# ####################
# Temperature: 0.2
# ####################
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# . .
#
#
#
#  y si no sabes lo que digo ,
# no me importa lo que haga ,
# no me importa lo que haga ,
# no me importa lo que haga ,
# no me digas que no me quieres ,
# no me dejes de soñar ,
# ya no quiero más ,
# quiero más que más que una ,
# que me recuerden que no ,
# que no , que no , que no . . .
#
#
#
#  no me digas que no me quieres ,
# que no me , que no , que no , que no , que no , que no , que no , que no , que no .
#
#
#
#  y si no me olvido ,
# no me arrepiento de nada ,
# por eso no creo en nada ,
# por eso es que ahora soy un loco ,
# y me lo paso paso a la cabeza ,
# y me lo tomo en cada página ,
# y a veces me gusta que me ,
# si me quieres , me quieres que te esperas ,
# me quieres joder , que te pegas ,
# te necesita un duro ,
# te lo juro , que no me ,
# que no me creo en nada ,
# pero no me arrepiento de nada ,
# de quererte , dejar de volar ,
# de sentir como el sol de la luna ,
# y el mundo se mueve en el cuello ,
# y yo no sé lo que es ,
# pero no lo sé , no sé ,
# no sé , no sé , no sé , no sé
#
# , de , de , de , de tipos de responsabilidad .
#
#
#
#  no quiero que me ,
# que me deje llevar , que me dejaré ir ,
# déjame sonar interesante ,
# no me tendrás que te cante ,
# no me pidas que te quiera ,
# si quieres que te cante , te ¿porque me dé ?
# que no te calles ni a la suela ,
# no me digas que no lo hago ,
# que no me digas que no me quieres ,
# no me dejes cerca de ti ,
# no te vayas a ,
# no te fíes de nadie ,
# si te vas a ver ,
# si no te lees , póntelo en tu carro ,
# si te mola esto es lo que te gusta ,
# y si no lo haces es porque no lo has hecho ,
# y si no lo hiciera yo ,
# y si no lo hago es lo que me gusta ,
# no me gusta el coco , no me gusta el trato ,
# no entiendo lo que estoy hablando ,
# si no me lo busco yo lo convierto en mi vida ,
# el romance era de otros tres ,
# donde había estaba dentro , di cuenta de nadie ,
# pa que estés . . .
# soy un crío , de intenciones
# se hace ver un mensaje para sonreír ,
# no es fácil tener todo y eso te decepción ,
# pero mira detrás como si va y la explosión no sabe nada ,
# o si de mí , si bien no me tengas , cuánto
#
# Epoch 21/30
# 3468/3468 [==============================] - 260s 75ms/step - loss: 3.1872
# Epoch 22/30
# 3468/3468 [==============================] - 261s 75ms/step - loss: 3.1615
# Epoch 23/30
# 3468/3468 [==============================] - 262s 76ms/step - loss: 3.1356
# Epoch 24/30
# 3468/3468 [==============================] - 262s 76ms/step - loss: 3.1075
# Epoch 25/30
# 3468/3468 [==============================] - 262s 76ms/step - loss: 3.0788
# ####################
# Temperature: 0.2
# ####################
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# , agujero ,
# hola , capitán , en mi sien ,
# si te lo rulando guapo ,
# te lo digo , no te importa lo que digas ,
# que no te , que no , que no ,
# que no me importa que me salve ,
# me alejo de lo que he sido ,
# he llorado con mi gente ,
# no soy un desconocido ,
# el amor es el único que más alto ,
# el que te hace el tiempo ,
# el tiempo no se para , yeh ,
# nos queda un cielo azul para un infierno ,
# y no hay nada que pueda hacer callar ,
# no podemos ,
# no pueden , no pueden , no pueden , no pueden
# no pueden conmigo , no pueden
# no pueden conmigo , no pueden conmigo
# no pueden aunque no me
#
#
#
#  no quiero que nadie me ni tampoco pedí perdón
# y no me importa que me hables de verdad ,
# no me importa lo que digas ,
# que no me , que no , que no , que no , que no , que no , que no . . .
#
#
#
#  no quiero recordarte ,
# quise ver como quiero ,
# no soy , no soy ,
# no soy el mejor , no soy un ,
# pero no me conformo , no , no , no , no ,
# no sé si no lo he hecho a mi ,
# pero no me conformo con ser feliz ,
# y si me oyes di que te quiero ,
# que me dices que no me gusta ,
# que
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ####################
# Temperature: 0.5
# ####################
# .
#
#
#
#
#
#
# no te quise separar lo peor ,
# que me dijiste que me ,
# que no , que fuiste mía , hoy me siento ,
# que me hagan daño , no me queda nada .
#
#
#
#  yo vine a ser de enamorarme de la paz ,
# de la que se hizo la miel ,
# en la cara la como pasajera ,
# yo soy un loco sin parar de jugar ,
# y si hay algo que no se cree tú que hayan hecho lo que
# no me fío de nadie , tengo mi proyecto .
# es un rap de , y mi rap es un
# y es que no me deja ni que me levante ,
# y que el tiempo se haga interior ,
# y que arda la utopía y que el sol se para ,
# mi corazón , mi alma , mi rincón , mi fuego , mi fuego , mi fuego , mi equipaje
# este es mi deporte , es un nuevo comienzo ,
# pero de la sombra ,
# nadie sabe lo que le mete ,
# y no le dan miedo al espejo ,
# se lanza en la esquina ,
# y me quema dentro , que la garganta se pierde ,
# no se puede estar lleno ,
# por eso digo que lo bueno se va por ti
# no soy lo que soy , no lo puedo entender ,
# por eso me mantengo fuerte .
#
#
#
#  y es que no sé cómo no sé ,
# que no soy la que se expande ,
# química dame un plato caliente y negro ,
#
#
# no me importa que me lleve ,
# si me estoy aquí ,
# si estoy de party no me ,
# me gusta el rap , prefiero no hacer bulto ,
# no es un juego , es un triste ,
# pero no me , no me gusta lo que encuentro ,
# no hay más ,
# el que te quiere , pero quiere meter el polvo en la cocina ,
# el humo que viví , el rey de la luna ,
# el hijo bastardo que me aprieta el ,
# y que no te , no ,
# no es justo el día que me quede en mi sitio ,
# no me importa que el destino ,
# no me preguntes , pero no puedo estar ,
# sólo me imagino si tú no estás ,
# no te hablo de tu cara ,
# y si la vida es el momento que me quito la venda ,
# y a mí me gusta lo que debo hacer ,
# y no , que no me , que no me ,
# que no me , que no me , que no me ,
# que no me , que no me , que no ,
# que no me importa que me salve ,
# no me digas que no me lord ,
# que no me , que no , que no , que no , que no . . .
#
#
#
#  y ahora que no . . .
#
#
#
#  damas y caballeros .
# está en juego el ganador ,
# fáciles ideas , eso no cuadra como un de
# y no te preocupes , no , no se me
#
# una misión ,
# y que siempre lo tuve que hacer ,
# que el tiempo nos fue y que nos lleve a .
#
#
#
#  y quiero que me hables de verdad ,
# no quiero que te abra ,
# si me miras , no me dejes engañar por ti
# te nadando en mi , y te gané el respeto ,
# el dinero negro y la carne , el tiempo de vivir ,
# la vida es un ,
# y si te vas a buscar ,
# la excusa de mirar hacia atrás .
#
#
# ( x2 )
# no lo sabes pro , fama ,
# no me hables de si te las ,
# ya no sé qué hacer , hoy me siento ,
# no me hables de quizás pero no te llevas mejor
# pero no debes pararte y no
# esto no es real , no es el tuyo ,
# porque no seas pesado , que te lo pone crudo
# y a que no lo sé , es lo cierto de lo que escribo .
#
#
# ( x2 )
# no hay nada que me ,
# ¿tu lo harías ?
# el rap es puro ,
# si no fuera por los míos te ,
# no tengas miedo a que me muera ,
# si no me encuentro ,  por cierto no quiero salvarme
# miento y quiero el vacío porque quiero ser
# quiero vivir sin paisaje para ser un
#
#
#
#  con la cabeza alta , no me puede y me fijo
# que si no me va a gustar
# no me los pierdas , te digo que eres feliz con el corazón .
#
#
# ####################
# Temperature: 1.0
# ####################
# idiomas dile ,
# la mierda somos abuso en plan y ,
# las personas se . palabras para un rato
#
#
#
#  últimamente aquí no armonía pueden hacer un mono ,
# ya te creí en la oreja hay cuestiones de en plano ,
# subidón de la hasta todas partes ,
# todas las rimas y los días
# el sol porque llego aquí no es
# quien pone el nombre de todos somos lo que hacemos yo ,
# lo advierto por mis problemas que no quiero contarte
# en esto pero no puedo mas y fluyo
# no quiero sentir el fin
# a alguien que a veces puedo perder todo el tiempo ya se hace ,
# y el tiempo no se lleva a perder , el .
# lo único que digas , siempre es mi forma ,
# nena lo que sientes .
# esta es la historia que motiva
# es mejor cuando salte la rato . . .
# un mortal recuerdo en sus piernas .
#
#
# ( x2 )
# odiar a mi familia
# you bon voyage
# out the down on your while comer guapas - sintiendo lay sí .
#
#
# one two three . .
# tú triste balada , reina , largas advierto ,
# tú eres tu sueño , ¿tú ? eres el cielo en tus ,
# hoy te de mi , yo por ti ,
# por tú y . ¿para qué ?
# he subido al tren . . . se en asco
# al pueblo le das derecho a perder , mata .
# me a mí o en exceso te lo hice bien .
#
#  diamante son ansias alma se tiran
#
# sea lo que te espera
# y decías que todo a una bala que pueda cuando ,
# la única que más da , cada lunes se vuelan los gatos ,
# a tu madre , a tu beneficio que para mi eres ,
# no por querer esto , pido perdón ,
# hoy nadie me dijo ,
# hoy hay luna , sí quiero las penas en mi cama ,
# toda la mejor mierda de mis versos ,
# y las historias de siempre ,
# ya tantos como jóvenes , sin perdón ,
# sin precio , sin ganas de retroceder
# perdido en el mismo instante
# dar con ser
# que bienestar existe
# te matan jodiendo a tus padres y acabarás
# sin que ni él , nos todos viven al límite ,
# todos las zapatillas que se , se compra su sufrimiento y aún no debí hacerlo ,
# los recuerdos aun son ,
# a veces me muevo y me como un del natural
# después yo sigo mi drama
# prefiero un drama
# aprendí mis logros , pero a veces se asfixia ,
# no hay que la salve el barrio , en el 90 que nene
# se me acabará , ningún le corto flex .
# ellos dicen cuando alguien dice pantalla ,
# me ha regalado de verdad aunque no pienses correr
# mira , el tiempo cambia toda una historia
# lo que has hecho sentir !
# y espero la triste que me pesa en la plaza
# qué siempre estoy yo , por ti le entreno
# a lo mejor no hay ta madre
# y vuelve o no va tan mal ? una ídolo o yo .
# está en mi
#
# , deja ya de pensar ,
# ¿qué pagan por si sueño , sin adiós .
# haz lo que quieras sobre mí . . .
#
#
# yeah . . . que digan color si están tienen agallas .
# ( estribillo )
#
#  niños que se creen que sería más bien , de las horas con él ,
# ni nervioso , ella era el problema .
# día tras día se nos da alas y mata el tiempo en que no nunca amarga haría .
#
#
# vacilar buscando otro fallo de esa de un don ,
# en el casino de alambre para san .
# cada beso que pienso delante
# aquello que cuesta fin .
# : ‘ me haz lo y ’ t ’ ,
# el que no parte el , el capitalismo ,
# lo que nos gusta es un ritual al barrio ,
# a la luz cuando llego el sol ,
# no sabe quién es , pero no son más
# pero al final me está mintiendo .
# aunque hay mil opciones , querer tragar , tienes que encontrar ,
# hay que luchar , luchar toda y la verdad que se siente
# que fiesta en ese estado con los ojos que os ponen ,
# me gusta decir que me gustas y yo ser como durmiendo en un directo
# cuantos años después de tanto tiempo
# se olvidaron de clase o se lo merece ,
# dile que los mato siempre hay un millón ,
# quiero que llevo mucho más allá de lo bueno que pasó
# nunca se quien eres
# y vuelve cual vas de vergüenza pero me mientes por mi casa
# ellos saben lo que suelto
#
# Epoch 26/30
# 3468/3468 [==============================] - 262s 75ms/step - loss: 3.0537
# Epoch 27/30
# 3468/3468 [==============================] - 261s 75ms/step - loss: 3.0250
# Epoch 28/30
# 3468/3468 [==============================] - 264s 76ms/step - loss: 2.9929
# Epoch 29/30
# 3468/3468 [==============================] - 262s 76ms/step - loss: 2.9633
# Epoch 30/30
# 3468/3468 [==============================] - 263s 76ms/step - loss: 2.9380
# ####################
# Temperature: 0.2
# ####################
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ella , yo por ti y por mi yo ,
# por ti , por mi boca , por mi madre , por mi pasta ,
# por mi , por mi equipo , por mi music ,
# por mi familia , por mi gente , por mi culpa ,
# por mi gente , por la gente y por su gente ,
# por los que miren , por las que se han equivocado ,
# y he perdido la fe en el corazón de los míos
# y si me encuentro es muy fuerte
# porque la segunda no es sacrificio
# solo por eso estoy en la cama
# y en mi cama
# con el corazón roto
# si no te gusta , cuida tus espaldas
# y te vas a ver ,
#
#
#
#  es mejor , es una ,
# un tema que no se rinde , y no hay que esperar ,
# que no hay nada que ver ,
# dime si es como quieres ver ,
# ¿dónde están los que no quedan ?
# ¿dónde están las lágrimas de esos años ?
# las nubes se van , el cielo arde
# si es que nos salimos a parar
# pero no nos vamos a buscar
# no , no
#
# ####################
# Temperature: 1.0
# ####################
# vienes si ?
# prefiero que me esos chavales ,
# loco por besar el colchón ,
# fumando buscando una peli de
# su ingenio al diablo , .
#
#
#
#  le meto a la luna , blanco de negro ,
# el acento de las es el amigo , en el barrio bizness juega
# es uno mismo desde el infierno
# esto ha muerto no tengo la batalla
# asi que eres sin sabor , actitud y no ,
# soy pieles que son oigo mis ansias y eso es mas barato
# y ya es porque estoy bien y no
# que en cada parte
# de actores que no paran algo distinta
# hay una rosa que sobrio como eterno
#
#
# de hielo , no te el motivo ,
# tu , vuelve la función de tu millón ,
# cerrando los bares , la fortuna ,
# pa´ muchos se para hacer que esto pase poco de no ,
# aprendí de una mano que perdió su fin
# que me separe , y me luce el mundo ,
# sé que es muy normal , escapar ,
# con mi hijo de la sangre que le seca
# el mundo gira en la vida , se encierra y busca . . .
# ver como nada pasas claro , ¿no ? ,
# cambio cambiar por vida , como lo ,
# ya me ves sin decir adiós , caí sincero corriendo los días ,
# es más andalucía de ara .
# aún no me importa lo que piensen los pasarme las vacíos ,
# donde mis sentimientos no barco ,
# hoy solo me encuentro en lo mío solo ,
# nunca te quiero una fortuna y
#
# balón .
#
#
# ( x2 )
# oh no , solo quiero que la just tregua .
# ella ha lo rompo , ella tiene lo que me ,
# me dio igual recordar , con qué educación de amor , y volvió a perderme
#
#
# ( x2 )
# es fácil de cambiar el mundo
# miedo a perder a perder después de la cartera ,
# cuándo problemas , creo que soy la chica mas ,
# para los vacíos quiero dejar de comer ,
# los ' , y a mi ,
# no si le prefieren hacer el mundo al rap
# cuando está a serpientes muy tonto cuando no las ves ,
# es la sonrisa que está ,
# el trastorno - voz ,
# en este instante y esa razón se hace más fuerte , civiles . ansío ,
# clavo tu mundo en cada cóctel ¿sabes ? , soy para tí
# brilla el agua .
# ¿me lo de venir a viajar al sol mi primavera ?
#
#  cuando por esta locura , y no un lío ,
# los rayos dónde ,
# sin dueños del río ,
# si esto es música y música pesao ,
# es encierro better un hombre - e de todo . . .
# me paso de noche , vamos pa ' la puerta ,
# y ando en mi casa con el cáncer en el recuerdo
# y por su mama sonríe también el ego
# y los comes la plata buscas algo nuevo en mis bolsillos ,
# y lo llevo una ignorancia ,
# sigo en línea nefasto , como un vuelo sería un vaso ,
# esta my life hit rap bajo un
#
# pa ' all huellas ,
# y en mi eclipse ya me verás que casi nada hear me
# catch it no estás over , here ’ s ,
# sing i - wanna shot .
# so i see the night tope a d ' el hate it now ,
# me con su sonrisa ' e hijoputa a de ,
# but i ' m ve to ' con la sonrisa ,
# y esta fiesta ya no me queda flores ni gota en el agota
# la musa sin ningún motivo para ver
# pienso en tus labios . pero te juro que la jugamos .
# no he parado en mp3 ,
# ni a nadie detrás la conocí y los de arriba ya me arrastra
# y a ver qué viendo yo , sola como es feo
# he visto tanta gente que queda en mi párpados .
# sin embargo , es temprano y salir fuera ,
# como yo como ninguno de los medios ,
# como el jugador de pero el 7 alta som búscame .
# queen entra en el black , estilo city ,
# okay - o el día perdido ,
# la foto ah , mirada sobre la locura , entre los mas sabios ,
# la cura de mi rima son lo despedida ,
# lo que nunca no se compra .
# la barca sigue sin bajar a di
# dinero de polen y perras ,
# la gente y no te lo pido , vine para quedarme ciego al límite y sonría ,
# mi vida es dura y te la clava ,
# el que dijo que , el que diga : sí ,
# que a cualquiera de disco nos han ,

# %% [markdown]
# You can download a large amount of generated text from your model with the cell below! Rerun the cell as many times as you want for even more text!

# %%
# this temperature schedule cycles between 1 very unexpected token, 1 unexpected token, 2 expected tokens, repeat.
# changing the temperature schedule can result in wildly different output!
temperature = [1.0, 0.5, 0.2, 0.2]   
prefix = None   # if you want each generated text to start with a given seed text

if train_cfg['line_delimited']:
  n = 1000
  max_gen_length = 60 if model_cfg['word_level'] else 300
else:
  n = 1
  max_gen_length = 2000 if model_cfg['word_level'] else 10000
  
timestring = datetime.now().strftime('%Y%m%d_%H%M%S')
gen_file = '{}_gentext_{}.txt'.format(model_name, timestring)

textgen.generate_to_file(gen_file,
                         temperature=temperature,
                         prefix=prefix,
                         n=n,
                         max_gen_length=max_gen_length)
files.download(gen_file)

# %% [markdown]
# You can download the weights and configuration files in the cell below, allowing you recreate the model on your own computer!

# %%
files.download('{}_weights_bnn.hdf5'.format(model_name))
files.download('{}_vocab_bnn.json'.format(model_name))
files.download('{}_config_bnn.json'.format(model_name))

# %% [markdown]
# To recreate the model on your own computer, after installing textgenrnn and TensorFlow, you can create a Python script with:
#
# ```
# from textgenrnn import textgenrnn
# textgen = textgenrnn(weights_path='colaboratory_weights.hdf5',
#                        vocab_path='colaboratory_vocab.json',
#                        config_path='colaboratory_config.json')
#
# textgen.generate_samples(max_gen_length=1000)
# textgen.generate_to_file('textgenrnn_texts.txt', max_gen_length=1000)
# ```
#
# Have fun with your new model! :)

# %% [markdown]
# # Etcetera
#
# If the model fails to load on a local machine due to a model-size-not-matching bug (common in >30MB weights), this is due to a file export bug from Colaboratory. To work around this issue, save the weights to Google Drive with the two cells below and download from there.

# %%
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from google.colab import files
from oauth2client.client import GoogleCredentials

auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
uploaded = drive.CreateFile({'title': '{}_weights.hdf5'.format(model_name)})
uploaded.SetContentFile('{}_weights.hdf5'.format(model_name))
uploaded.Upload()
print('Uploaded file with ID {}'.format(uploaded.get('id')))

# %% [markdown]
# If the notebook has errors (e.g. GPU Sync Fail), force-kill the Colaboratory virtual machine and restart it with the command below:

# %%
# !kill -9 -1
